# %%
#!pip install requests

# %%
import requests

# %%
import json
import pandas as pd

# %%
LOGIN_URL = 'https://api.wrnch.ai/v1/login'
JOBS_URL = 'https://api.wrnch.ai/v1/jobs'

# %%
API_KEY = "1391ce51-1c4b-4ff7-8298-a4f952e5cfc6"

# %%
resp_auth = requests.post(LOGIN_URL,data={'api_key':API_KEY})
print(resp_auth.text)
# the jwt token is valid for an hour
JWT_TOKEN = json.loads(resp_auth.text)['access_token']
# Out:
# {"access_token": "eyJhbGciOiJIUzI1NiJ9..TBjSOmTIMOvcvv5IUTWCqI_zDqnAz9hxBMz_RHNifWQ"}

# %%
with open('Pictures/video5.mp4', 'rb') as f:
    resp_sub_job = requests.post(JOBS_URL,
                                 headers={'Authorization':f'Bearer {JWT_TOKEN}'},
                                 files={'media':f},
                                 data={'work_type':'json'}
                                )

# %%
job_id = json.loads(resp_sub_job.text)['job_id']
print('Status code:',resp_sub_job.status_code)
print('Response:',resp_sub_job.text)
# Out:
# Status code: 202
# Response: {"job_id": "47455bda-b1e9-4c78-96f6-cb4dce0a6d45"}

# %%
GET_JOB_URL = JOBS_URL + '/' +job_id
print(GET_JOB_URL)
resp_get_job = requests.get(GET_JOB_URL,headers={'Authorization':f'Bearer {JWT_TOKEN}'})
print('Status code:',resp_get_job.status_code)
print('\nResponse:',resp_get_job.text)
# Out:
# https://api.wrnch.ai/v1/jobs/47455bda-b1e9-4c78-96f6-cb4dce0a6d45
# Status code: 200
#
# ...

# %%
print(resp_get_job.text)
# Out:
# {"file_info":{"duration":6,"frame_rate":30.0,"joint_definitions":{"hands":"hand21","head":"wrFace20","pose2d":"j25","pose3d_ik":"extended","pose3d_raw":"j25"}},"frames":[{"frame_time":0,"height":1280,"persons":[{"id":0,"pose2d":{"bbox":{"height":0.8623396754264832,"minX":0.1109122484922409,"minY":0.22252903878688812,"width":0.918674647808075},"is_main":true,"joints":[0.44920605421066284,1.012965440750122,0.45308157801628113,0.8811364769935608,0.4297805428504944,0.7031159996986389,0.6406410932540894,0.7009623646736145,0.628958523273468,0.8810955286026001,0.6250471472740173,1.0130070447921753,0.5352108478546143,0.7020392417907715,0.5352147817611694,0.4164074659347534,0.538966178894043,0.41744041442871094,0.5400390625,0.29883185029029846,0.18746846914291382,0.6876996159553528,0.2890142500400543,0.5515556931495667,0.36332041025161743,0.41750437021255493,0.7071090936660767,0.4153105318546295,0.7970056533813477,0.5471078753471375,0.9530306458473206,0.674505352973938,0.542905867099762,0.314
# ...

# %%
cloud_pose_estimation = json.loads(resp_get_job.text)

# %%
import winsound

# %%
print(len(cloud_pose_estimation['frames']))
# Out:
# 279

# %%
for e in cloud_pose_estimation['frames'][5::30]:
    #LWRIST AND LEAR
    if (e['persons'][0]['pose2d']['joints'][31] > 0 and e['persons'][0]['pose2d']['joints'][39] > 0 and abs(e['persons'][0]['pose2d']['joints'][31] - e['persons'][0]['pose2d']['joints'][39]) <= 0.05):
        print("ears")
        winsound.PlaySound('notes/c2-2.wav',winsound.SND_ASYNC)
        winsound.PlaySound('notes/c2-2.wav',winsound.SND_PURGE)    

    #LWRIST AND LKNEE
    elif (e['persons'][0]['pose2d']['joints'][31] > 0 and e['persons'][0]['pose2d']['joints'][9] > 0 and abs(e['persons'][0]['pose2d']['joints'][31] - e['persons'][0]['pose2d']['joints'][9]) <= 0.15):
        winsound.PlaySound('notes/E2-2.wav',winsound.SND_ASYNC)
        winsound.PlaySound('notes/E2-2.wav',winsound.SND_PURGE)
        print("knee")
    #LWRIST AND LHIP
    elif (e['persons'][0]['pose2d']['joints'][31] > 0 and e['persons'][0]['pose2d']['joints'][7] > 0 and abs(e['persons'][0]['pose2d']['joints'][31] - e['persons'][0]['pose2d']['joints'][7]) <= 0.05):
        print("hip")
        winsound.PlaySound('notes/G2-2.wav',winsound.SND_ASYNC)
        winsound.PlaySound('notes/G2-2.wav',winsound.SND_PURGE)    

        #LWRIST AND LTOE
    elif (e['persons'][0]['pose2d']['joints'][31] > 0 and e['persons'][0]['pose2d']['joints'][45] > 0 and abs(e['persons'][0]['pose2d']['joints'][31] - e['persons'][0]['pose2d']['joints'][45]) <= 0.1):
        print("toe")
        winsound.PlaySound('notes/D2-2.wav',winsound.SND_ASYNC)
        winsound.PlaySound('notes/D2-2.wav',winsound.SND_PURGE)
    
    #RIGHT SIDE
    
    #RWRIST AND REAR
    elif (e['persons'][0]['pose2d']['joints'][21] > 0 and e['persons'][0]['pose2d']['joints'][37] > 0 and abs(e['persons'][0]['pose2d']['joints'][21] - e['persons'][0]['pose2d']['joints'][37]) <= 0.1):
        print("Rears")
        winsound.PlaySound('notes/A2-2.wav',winsound.SND_ASYNC)
        winsound.PlaySound('notes/A2-2.wav',winsound.SND_PURGE)    

    #RWRIST AND RKNEE
    elif (e['persons'][0]['pose2d']['joints'][21] > 0 and e['persons'][0]['pose2d']['joints'][3] > 0 and abs(e['persons'][0]['pose2d']['joints'][21] - e['persons'][0]['pose2d']['joints'][3]) <= 0.15):
        winsound.PlaySound('notes/B2-2.wav',winsound.SND_ASYNC)
        winsound.PlaySound('notes/B2-2.wav',winsound.SND_PURGE)
        print("Rknee")
    #RWRIST AND RHIP
    elif (e['persons'][0]['pose2d']['joints'][21] > 0 and e['persons'][0]['pose2d']['joints'][5] > 0 and abs(e['persons'][0]['pose2d']['joints'][21] - e['persons'][0]['pose2d']['joints'][5]) <= 0.07):
        print("Rhip")
        winsound.PlaySound('notes/c3.wav',winsound.SND_ASYNC)
        winsound.PlaySound('notes/c3.wav',winsound.SND_PURGE)    

    #RWRIST AND RTOE
    elif (e['persons'][0]['pose2d']['joints'][21] > 0 and e['persons'][0]['pose2d']['joints'][43] > 0 and abs(e['persons'][0]['pose2d']['joints'][21] - e['persons'][0]['pose2d']['joints'][43]) <= 0.1):
        print("Rtoe")
        winsound.PlaySound('notes/F2.wav',winsound.SND_ASYNC)
        winsound.PlaySound('notes/F2.wav',winsound.SND_PURGE)
    else:
        winsound.PlaySound(None, winsound.SND_ASYNC)
        winsound.PlaySound(None, winsound.SND_PURGE)
# Out:
# Rhip
# ears
# Rears
# hip
# Rears
# Rhip
# knee
# ears
# ears

# %%
print()
